# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from DBM import DielectricBreakdown

# %%
db = DielectricBreakdown(
    N=100, 
    seed_mode='point', 
    eta=1, 
    triangle_theta=90, 
    triangle_height=40
)
steps = db.simulate()

# Visualization
db.plot_overlay()
# Out:
# Breakdown reached top at step 1160.

# %%
test = DielectricBreakdown()
test.spark_dict = test.load_content('data.pkl')
test.plot_spark()
